# %% [markdown]
# <a href="https://colab.research.google.com/github/mturisamson69-tech/mmu-bike-rentals/blob/main/untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ohm's Law Calculator

try:
    voltage = float(input("Enter voltage (V): "))
    resistance = float(input("Enter resistance (Ohms): "))

    if resistance != 0:
        current = voltage / resistance
        print("Current (A):", current)
    else:
        print("Error: Resistance cannot be zero")

except ValueError:
    print("Error: Please enter valid numbers only")
# Out:
# Enter voltage (V): 12
# Enter resistance (Ohms): 5
# Current (A): 2.4
